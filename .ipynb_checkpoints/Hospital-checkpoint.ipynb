# %%
"""
This is a Python program of hospital database management that would be 
beneficial for the hospital receptionist to obtain information related 
to patients, doctors, and patient's medical history.

--------------------------------------------------------------------------
"""
import mysql.connector
from datetime import datetime

#------------------------------------------------------------------------#
# Hospital Class                                                         #
#------------------------------------------------------------------------#
class Hospital:
    pass


#------------------------------------------------------------------------#
# Doctor Class                                                           #
#------------------------------------------------------------------------#
class Doctor:
    def register_doctor(self):
        doc_name = input("Enter name of doctor: ")
        doc_edu = input("Enter your qualification: ")
        doc_speciality = input("Enter your specialization: ")
        doc_availability = input("Enter Availability(Mon, Tue, Wed, Thu, Fri, Sat, Sun): ")
    
    
    
#------------------------------------------------------------------------#
# Patient Class                                                          #
#------------------------------------------------------------------------#
class Patient:
    def register_patient(self):
        patient_name = input("Enter patient's full name: ")
        patient_dob = validate_DOB(input("Enter Date of Birth (yyyy-mm-dd): "))
        patient_address = input("Enter Address: ")
        patient_phone = validate_mobile_no(input("Enter valid 10-digit Mobile number containing only digits: "))
        patient_email = input("Enter email ID: ")
        try:
            mydb = mysql.connector.connect(host="localhost",user="root", passwd="aakash", database="hospital")
            mycursor = mydb.cursor()
            query = "INSERT INTO `hospital`.`patient` (`patient_name`,`patient_dob`,`patient_address`,\
            `patient_phone`,`patient_email`) VALUES (%s,%s,%s,%s,%s)"
            values = (patient_name,patient_dob,patient_address,patient_phone,patient_email)
            mycursor.execute(query, values)
            mydb.commit()
            print("Record Added Successfully!")
        except:
            print("Record of other patient with same mobile number already exists!")
            print("\nExisting Record:")
            mycursor = mydb.cursor()
            mycursor.execute("SELECT * FROM `hospital`.`patient` WHERE patient_phone = %s",(int(patient_phone),))
            myresult = mycursor.fetchall()
            for x in myresult:
                for i in x:
                    print(i)
            print("\nPatient detail not registered.")
            print("-----------------------------------------------------------")
    
    def search_patient(self):
        mydb = mysql.connector.connect(host="localhost",user="root", passwd="aakash", database="hospital")

        patient_num = [validate_mobile_no(input("Enter the mobile number of patient: "))]

        cursor = mydb.cursor()
        query = "SELECT * FROM `hospital`.`patient` WHERE `patient_phone` = %s"
        cursor.execute(query,patient_num)

        myresult = cursor.fetchone()
        if myresult:
            print(f"Name: {myresult[0]}\nDOB: {myresult[1]}\nAddress: {myresult[2]}\nPhone No.: {myresult[3]}\ne-Mail: {myresult[4]}")
        else:
            print("No record found. Please register patient.")
            self.register_patient()
        
#------------------------------------------------------------------------#
#                     VALIDATIONS (DOB and Mobile)                       #
#------------------------------------------------------------------------#

# Validate DOB
# Ref: https://www.geeksforgeeks.org/python-validate-string-date-format/
def validate_DOB(date):
    val_date = date
    while True:
        # initializing format 
        format = "%Y-%m-%d"
        # using try-except to check for truth value
        try:
            datetime.strptime(val_date, format)
            break
        
        except:
            print("Wrong Date!")
            val_date = input("Enter Date of Birth (yyyy-mm-dd): ")
    return val_date

#Validate Mobile Number
def validate_mobile_no(mobile_no):
    while not mobile_no.isdigit() or len(mobile_no) != 10:
            mobile_no = input("Enter a valid 10-digit Mobile number containing only digits: ")
    return mobile_no

patient = Patient()
patient.register_patient()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 105
#     102     return mobile_no
#     104 patient = Patient()
# --> 105 patient.register_patient()
#
# Cell In[1], line 35, in Patient.register_patient(self)
#      34 def register_patient(self):
# ---> 35     patient_name = input("Enter patient's full name: ")
#      36     patient_dob = validate_DOB(input("Enter Date of Birth (yyyy-mm-dd): "))
#      37     patient_address = input("Enter Address: ")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1187, in Kernel.raw_input(self, prompt)
#    1185     msg = "raw_input was called, but this frontend does not support input requests."
#    1186     raise StdinNotImplementedError(msg)
# -> 1187 return self._input_request(
#    1188     str(prompt),
#    1189     self._parent_ident["shell"],
#    1190     self.get_parent("shell"),
#    1191     password=False,
#    1192 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1230, in Kernel._input_request(self, prompt, ident, parent, password)
#    1227 except KeyboardInterrupt:
#    1228     # re-raise KeyboardInterrupt, to truncate traceback
#    1229     msg = "Interrupted by user"
# -> 1230     raise KeyboardInterrupt(msg) from None
#    1231 except Exception:
#    1232     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Trials

# %%
"""
This is a Python program of hospital database management that would be 
beneficial for the hospital receptionist to obtain information related 
to patients, doctors, and patient's medical history.

--------------------------------------------------------------------------
"""
import mysql.connector
from datetime import datetime

#------------------------------------------------------------------------#
# Hospital Class                                                         #
#------------------------------------------------------------------------#
class Hospital:
    def __init__(self):
        print("------------------------------------------")
        print("1. Patient\n2. Doctor")
        data = int(input("Choose the data you want to work with: "))
        if data == 1:
            patient = Patient()
        elif data == 2:
            doc = Doctor()
        else:
            print("\nENTER A VALID CHOICE!")
            hosp = Hospital()


#------------------------------------------------------------------------#
# Doctor Class                                                           #
#------------------------------------------------------------------------#
class Doctor:
    def register_doctor(self):
        doc_name = input("Enter name of doctor: ")
        doc_edu = input("Enter your qualification: ")
        doc_speciality = input("Enter your specialization: ")
        doc_availability = input("Enter Availability(Mon, Tue, Wed, Thu, Fri, Sat, Sun): ")
    
    
    
#------------------------------------------------------------------------#
# Patient Class                                                          #
#------------------------------------------------------------------------#
class Patient:
    def __init__(self):
        print("\n--------------------")
        print("1. Register New Patient\n2. Search Patient\n3. Schedule Appointment")
        pat_choice = int(input("Enter your selection:"))
        if pat_choice == 1:
            self.register_patient()
        elif pat_choice == 2:
            self.search_patient()
        elif pat_choice == 3:
            self.appointment_schedule()
        else:
            print("\nENTER A VALID CHOICE!")
            pat = Patient()
            
    def register_patient(self):
        patient_name = input("Enter patient's full name: ")
        patient_dob = validate_DOB(input("Enter Date of Birth (yyyy-mm-dd): "))
        patient_address = input("Enter Address: ")
        patient_phone = validate_mobile_no(input("Enter valid 10-digit Mobile number containing only digits: "))
        patient_email = input("Enter email ID: ")
        try:
            mydb = mysql.connector.connect(host="localhost",user="root", passwd="aakash", database="hospital")
            mycursor = mydb.cursor()
            query = "INSERT INTO `hospital`.`patient` (`patient_name`,`patient_dob`,`patient_address`,\
            `patient_phone`,`patient_email`) VALUES (%s,%s,%s,%s,%s)"
            values = (patient_name,patient_dob,patient_address,patient_phone,patient_email)
            mycursor.execute(query, values)
            mydb.commit()
            print("Record Added Successfully!")
        except:
            print("Record of other patient with same mobile number already exists!")
            print("\nExisting Record:")
            mycursor = mydb.cursor()
            mycursor.execute("SELECT * FROM `hospital`.`patient` WHERE patient_phone = %s",(int(patient_phone),))
            myresult = mycursor.fetchall()
            for x in myresult:
                for i in x:
                    print(i)
            print("\nPatient detail not registered.")
            print("-----------------------------------------------------------")
    
    def search_patient(self):
        mydb = mysql.connector.connect(host="localhost",user="root", passwd="aakash", database="hospital")

        patient_num = [validate_mobile_no(input("Enter the mobile number of patient: "))]

        cursor = mydb.cursor()
        query = "SELECT * FROM `hospital`.`patient` WHERE `patient_phone` = %s"
        cursor.execute(query,patient_num)

        myresult = cursor.fetchone()
        if myresult:
            print(f"Name: {myresult[0]}\nDOB: {myresult[1]}\nAddress: {myresult[2]}\nPhone No.: {myresult[3]}\ne-Mail: {myresult[4]}")
        else:
            print("No record found. Please register patient.")
            self.register_patient()
            
    def appointment_schedule(self):
        mydb = mysql.connector.connect(host="localhost",user="root", passwd="aakash", database="hospital")
        patient_num = [validate_mobile_no(input("Enter the mobile number of patient: "))]

        mycursor = mydb.cursor()
        query = "SELECT * FROM `hospital`.`patient` WHERE `patient_phone` = %s"
        mycursor.execute(query,patient_num)

        myresult = mycursor.fetchone()
        if myresult:
            pass

        else:
            print("No record found. Please register patient.")
            choice = int(input("Enter Choice (1 to register patient / 2 to re-enter number): "))
            if choice == 1:
                register_patient()
            elif choice == 2:
                appointment_schedule()
        
#------------------------------------------------------------------------#
#                     VALIDATIONS (DOB and Mobile)                       #
#------------------------------------------------------------------------#

# Validate DOB
# Ref: https://www.geeksforgeeks.org/python-validate-string-date-format/
def validate_DOB(date):
    val_date = date
    while True:
        # initializing format 
        format = "%Y-%m-%d"
        # using try-except to check for truth value
        try:
            datetime.strptime(val_date, format)
            break
        
        except:
            print("Wrong Date!")
            val_date = input("Enter Date of Birth (yyyy-mm-dd): ")
    return val_date

#Validate Mobile Number
def validate_mobile_no(mobile_no):
    while not mobile_no.isdigit() or len(mobile_no) != 10:
            mobile_no = input("Enter a valid 10-digit Mobile number containing only digits: ")
    return mobile_no

hospital = Hospital()
# Out:
# ------------------------------------------
# 1. Patient
# 2. Doctor
# Choose the data you want to work with: 1
#
# --------------------
# 1. Register New Patient
# 2. Search Patient
# 3. Schedule Appointment
# Enter your selection:2
# Enter the mobile number of patient: 8469704750
# No record found. Please register patient.
# Enter patient's full name: Mahir Kadia
# Enter Date of Birth (yyyy-mm-dd): 23165-10-12
# Wrong Date!
# Enter Date of Birth (yyyy-mm-dd): 2005-05-123
# Wrong Date!
# Enter Date of Birth (yyyy-mm-dd): 2005-05-12
# Enter Address: A'bad, 369874
# Enter valid 10-digit Mobile number containing only digits: 8469704750
# Enter email ID: ags@gmail.comm
# Record Added Successfully!

# %% [markdown]
# ### Please enter medical history to search patient function

# %% [markdown]
# jdhgfcjhbn;l'.;''
# lkjhgfdxxfcgvhbnjkm,l.;';lkjhgfdszdxfcghjk'

# %% [markdown]
# # RECORD CHECKER
# ```
# import mysql.connector
#
# mydb = mysql.connector.connect(
#     host="localhost",
#     user="root",
#     passwd="aakash",
#     database="hospital"
#     )
#
# # print(mydb.is_connected())
# try:
#     mycursor = mydb.cursor()
#
#     query = "INSERT INTO `hospital`.`patient` (`patient_name`,`patient_dob`,`patient_address`,`patient_phone`,`patient_email`)\
#     VALUES (%s,%s,%s,%s,%s)"
#
#     values = ("Aakash Prajapati","2001-04-20","12 Deep Bungalows,Satellite,A'bad,380015","8401364728","aakash.20042001@gmail.com")
#
#     mycursor.execute(query, values)
#
#     mydb.commit()
# except:
#     print("Record of patient with same mobile number already exists!")
# ```

# %% [markdown]
# # DOB CHECKER
#
# ``` def validate_DOB(date):
#     val_date = date
#     while True:
#         # initializing format
#         format = "%Y-%m-%d"
#         # using try-except to check for truth value
#         try:
#             datetime.strptime(val_date, format)
#             break
#
#         except:
#             print("Wrong Input!")
#             val_date = input("Enter Date of Birth (yyyy-mm-dd): ")
#     return val_date
#
# class New:
#     def __init__(self):
#         dt = validate_DOB(input("Enter Date of Birth (yyyy-mm-dd): "))
#         print(dt)
#
# new = New()
# ```

# %% [markdown]
# # MOBILE NO. CHECK
# ```
# def validate_mobile_no(mobile_no):
#         while not mobile_no.isdigit() or len(mobile_no) != 10:
#             print("Enter a valid 10-digit Mobile number containing only digits:")
#             mobile_no = input()
#         return mobile_no
#
# class New:
#     def __init__(self):
#         dt = validate_mobile_no(input("Enter Phone: "))
#         print(dt)
#
# new = New()
# ```

# %%
import mysql.connector
def validate_mobile_no(mobile_no):
    while not mobile_no.isdigit() or len(mobile_no) != 10:
            mobile_no = input("Enter a valid 10-digit Mobile number containing only digits: ")
    return mobile_no

def appointment_schedule():
    mydb = mysql.connector.connect(host="localhost",user="root", passwd="aakash", database="hospital")
    patient_num = [validate_mobile_no(input("Enter the mobile number of patient: "))]

    mycursor = mydb.cursor()
    query = "SELECT * FROM `hospital`.`patient` WHERE `patient_phone` = %s"
    mycursor.execute(query,patient_num)

    myresult = mycursor.fetchone()
    if myresult:
        pass

    else:
        print("No record found. Please register patient.")
        choice = int(input("Enter Choice (1 to register patient / 2 to re-enter number): "))
        if choice == 1:
            register_patient()
        elif choice == 2:
            appointment_schedule()
            
appointment_schedule()
# Out:
# Enter the mobile number of patient: 7894561230
# No record found. Please register patient.
# Enter Choice (1 to register patient / 2 to re-enter number): 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 27
#      24         elif choice == 2:
#      25             appointment_schedule()
# ---> 27 appointment_schedule()
#
# Cell In[4], line 23, in appointment_schedule()
#      21 choice = int(input("Enter Choice (1 to register patient / 2 to re-enter number): "))
#      22 if choice == 1:
# ---> 23     register_patient()
#      24 elif choice == 2:
#      25     appointment_schedule()
#
# NameError: name 'register_patient' is not defined

# %%
def foo():
    print("hello dear")
def cho():
    choice = input("Enter Y/N:")
    while True:
        if choice == "y" or choice == "Y":
            print("Hello")
            foo()
            break
        elif choice == "n" or choice == "N":
            print("Goodbye")
            break
        else:
            cho()
            break
    print("Hello")
cho()
# Out:
# Hello
# hello dear
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
"""
This is a Python program of hospital database management that would be 
beneficial for the hospital receptionist to obtain information related 
to patients, doctors, and patient's medical history.

Name: Aakash Kishanbhai Prajapati
Title: Hospital Database Management
Subject: FCSP-1
Enrollment No. : 23002170120001


--------------------------------------------------------------------------
"""

import mysql.connector
from datetime import datetime
from datetime import date

mydb = mysql.connector.connect(
    host="localhost", user="root", passwd="aakash", database="hospital"
)


# ------------------------------------------------------------------------#
# Hospital Class                                                         #
# ------------------------------------------------------------------------#
class Hospital:
    def __init__(self):
        print("\n---------------------------------------------------")
        print("MAIN MENU")
        print("---------------------------------------------------\n")
        print("1. Patient\n2. Doctor\n3. Exit")
        try:
            data = int(input("\nChoose the data you want to work with: "))
            if data == 1:
                patient = Patient()
            elif data == 2:
                doc = Doctor()
            elif data == 3:
                exit()
            else:
                print("\nENTER A VALID CHOICE!")
                hosp = Hospital()
        except ValueError:
            print("\nENTER A VALID CHOICE!")
            hosp = Hospital()


# ------------------------------------------------------------------------#
# Doctor Class                                                           #
# ------------------------------------------------------------------------#
class Doctor:
    def __init__(self):
        print("\n---------------------------------------------------")
        print("DOCTOR MENU")
        print("---------------------------------------------------\n")
        print("1. Register New Doctor\n2. Display All Doctors\n3. Return to main menu")
        try:
            doc_choice = int(input("\nEnter your selection: "))
            if doc_choice == 1:
                self.register_doctor()
            elif doc_choice == 2:
                self.display_doctor()
            elif doc_choice == 3:
                hospital = Hospital()
            else:
                print("\nENTER A VALID CHOICE!")
                doc = Doctor()
        except ValueError:
            print("\nENTER A VALID CHOICE!")
            doc = Doctor()

    def register_doctor(self):
        doc_name = input("Enter name of doctor: ")
        doc_edu = input("Enter qualification: ")
        doc_availability = input(
            "Enter Availability(Mon, Tue, Wed, Thu, Fri, Sat, Sun): "
        )
        doc_number = validate_mobile_no(
            input("Enter valid 10-digit Mobile number containing only digits: ")
        )

        try:
            mycursor = mydb.cursor()
            query = "INSERT INTO `hospital`.`doctor` (`doc_name`, `doc_edu`, `doc_days`, `doc_phone`) VALUES (%s,%s,%s,%s)"
            values = (doc_name, doc_edu, doc_availability, doc_number)
            mycursor.execute(query, values)
            mydb.commit()
            print("Record Added Successfully!")
            self.__init__()
        except:
            print("Record of other doctor with same mobile number already exists!")
            print("\nExisting Record:")
            mycursor = mydb.cursor()
            mycursor.execute(
                "SELECT * FROM `hospital`.`doctor` WHERE doc_phone = %s", (doc_number,)
            )
            myresult = mycursor.fetchall()
            for x in myresult:
                for i in x:
                    print(i)
            print("\n---------------------------------------------------")
            print("Doctor detail not registered.")
            print("---------------------------------------------------\n")
            self.__init__()

    def display_doctor(self):
        mycursor = mydb.cursor()
        mycursor.execute("SELECT * FROM `hospital`.`doctor`")
        myresult = mycursor.fetchall()
        if myresult:
            print("\n---------------------------------------------------")
            print("DOCTORS")
            print("---------------------------------------------------")
            for index, value in enumerate(myresult):
                print(
                    f"\n{index+1}.\nName: {value[0]}\nDoctor Qualification: {value[1]}\nAvailability: {value[2]}\nPhone No.: {value[3]}\n"
                )
            print("---------------------------------------------------")
            self.__init__()
        else:
            print("No Doctors Registered")
            self.__init__()

    # show all appointments for doctor


# ------------------------------------------------------------------------#
# Patient Class                                                          #
# ------------------------------------------------------------------------#
class Patient:
    def __init__(self):
        print("\n---------------------------------------------------")
        print("PATIENT MENU")
        print("---------------------------------------------------\n")
        print(
            "1. Register New Patient\n2. Search Patient\n3. Schedule Appointment\n4. Return to main menu"
        )
        try:
            pat_choice = int(input("\nEnter your selection: "))
            if pat_choice == 1:
                self.register_patient()
            elif pat_choice == 2:
                self.search_patient()
            elif pat_choice == 3:
                self.appointment_schedule()
            elif pat_choice == 4:
                hospital = Hospital()
            else:
                print("\nENTER A VALID CHOICE!")
                pat = Patient()
        except ValueError:
            print("\nENTER A VALID CHOICE!")
            pat = Patient()

    def register_patient(self):
        patient_name = input("Enter patient's full name: ")
        patient_dob = validate_DOB(input("Enter Date of Birth (yyyy-mm-dd): "))
        patient_address = input("Enter Address: ")
        patient_phone = validate_mobile_no(
            input("Enter valid 10-digit Mobile number containing only digits: ")
        )
        patient_email = input("Enter email ID: ")
        try:
            mycursor = mydb.cursor()
            query = "INSERT INTO `hospital`.`patient` (`patient_name`,`patient_dob`,`patient_address`,\
            `patient_phone`,`patient_email`) VALUES (%s,%s,%s,%s,%s)"
            values = (
                patient_name,
                patient_dob,
                patient_address,
                patient_phone,
                patient_email,
            )
            mycursor.execute(query, values)
            mydb.commit()
            print("Record Added Successfully!")
            self.__init__()
        except:
            print("Record of other patient with same mobile number already exists!")
            print("\nExisting Record:")
            mycursor = mydb.cursor()
            mycursor.execute(
                "SELECT * FROM `hospital`.`patient` WHERE patient_phone = %s",
                (int(patient_phone),),
            )
            myresult = mycursor.fetchall()
            for x in myresult:
                for i in x:
                    print(i)
            print("\nPatient detail not registered.")
            print("\n---------------------------------------------------")
            self.__init__()

    def search_patient(self):
        patient_num = [
            validate_mobile_no(input("Enter the mobile number of patient: "))
        ]

        cursor = mydb.cursor()
        query = "SELECT * FROM `hospital`.`patient` WHERE `patient_phone` = %s"
        cursor.execute(query, patient_num)

        myresult = cursor.fetchone()

        print("\n---------------------------------------------------")

        if myresult:
            print("Patient Details:\n")
            print(
                f"Name: {myresult[0]}\nDOB: {myresult[1]}\nAddress: {myresult[2]}\nPhone No.: {myresult[3]}\ne-Mail: {myresult[4]}"
            )
            print("---------------------------------------------------\n")
            self.__init__()
        else:
            while True:
                choice = input(
                    "No record found. Do you want to register the patient? (Y/N): "
                )
                if choice == "y" or choice == "Y":
                    self.register_patient()
                    break
                elif choice == "n" or choice == "N":
                    self.__init__()
                    break
                else:
                    print("\nENTER A VALID CHOICE!")
                    self.__init__()
                    break

    def appointment_schedule(self):
        patient_num = [
            validate_mobile_no(input("Enter the mobile number of patient: "))
        ]

        mycursor = mydb.cursor()
        query = "SELECT * FROM `hospital`.`patient` WHERE `patient_phone` = %s"
        mycursor.execute(query, patient_num)
        myresult = mycursor.fetchone()
        if myresult:
            print(
                f"\nName: {myresult[0]}\nDOB: {myresult[1]}\nAddress: {myresult[2]}\nPhone No.: {myresult[3]}\ne-Mail: {myresult[4]}"
            )
            mycursor = mydb.cursor()
            query = "SELECT * FROM `hospital`.`doctor`"
            mycursor.execute(query)
            myresult = mycursor.fetchall()
            print("\nDoctors:")
            for index, doctor in enumerate(myresult):
                print(f"{index+1}. {doctor[0]} ,{doctor[1]}, Available: {doctor[2]}")

            try:
                choose_doctor = int(
                    input(
                        "\nEnter the index number of doctor to select them for appointment: "
                    )
                )
                if choose_doctor > len(list(enumerate(myresult))):
                    print("Invalid choice")
                    self.appointment_schedule()
                else:
                    checkDay(doctor[2])
                    # appointment_time = input(
                    #     "Enter the time you want to select for appointment: "
                    # )

                    # mycursor = mydb.cursor()
                    # query = "INSERT INTO `hospital`.`appointment` (`appointment_date`,`appointment_time`,`appointment_doctor`,`appointment_patient`) VALUES (%s,%s,%s,%s)"
                    # values = (datetime.now().strftime("%Y-%m-%d"),datetime.now().strftime("%H:%M:%S"),choose_doctor,patient_num)
                    # mycursor.execute(query, values)
                    # mydb.commit()
                    # print("Appointment Scheduled Successfully!")
                    # self.__init__()
            except ValueError:
                print("Invalid choice")
                self.appointment_schedule()

        else:
            print("\nNo record found. Please register patient.")
            try:
                while True:
                    choice = int(
                        input(
                            "\nEnter Choice (1 to register patient / 2 to re-enter number): "
                        )
                    )
                    if choice == 1:
                        self.register_patient()
                        break
                    elif choice == 2:
                        self.appointment_schedule()
                        break
                    else:
                        print("Invalid choice")

            except ValueError:
                print("Invalid choice")
                self.appointment_schedule()


# ------------------------------------------------------------------------#
#                     VALIDATIONS (DOB and Mobile)                       #
# ------------------------------------------------------------------------#


# Validate DOB
# Ref: https://www.geeksforgeeks.org/python-validate-string-date-format/
def validate_DOB(date):
    val_date = date
    while True:
        # initializing format
        format = "%Y-%m-%d"
        # using try-except to check for truth value
        try:
            datetime.strptime(val_date, format)
            break

        except:
            print("Wrong Date!")
            val_date = input("Enter Date of Birth (yyyy-mm-dd): ")
    return val_date


# Validate Mobile Number
def validate_mobile_no(mobile_no):
    while not mobile_no.isdigit() or len(mobile_no) != 10:
        mobile_no = input(
            "Enter a valid 10-digit Mobile number containing only digits: "
        )
    return mobile_no

def validate_date(dates):
    while True:
        # initializing format
        format = "%Y-%m-%d"
        # using try-except to check for truth value
        try:
            datetime.strptime(dates, format)
            break

        except:
            print("Wrong Date!")
            dates = input("Enter Date: ")
    return dates


def checkDay(available_day):
    init_date = input("\nEnter Date (yyyy-mm-dd): ")
    dates = validate_date(init_date)
    year, month, day = dates.split("-")
    selected_day = date(int(year), int(month), int(day)).strftime("%A")
    if selected_day[:3] in available_day:
        return dates
    else:
        print("Doctor not available on selected date! Please choose another date.")
        return checkDay(available_day)

hospital = Hospital()
# Out:
# ---------------------------------------------------
# MAIN MENU
# ---------------------------------------------------
#
# 1. Patient
# 2. Doctor
# 3. Exit
#
# Choose the data you want to work with: 1
#
# ---------------------------------------------------
# PATIENT MENU
# ---------------------------------------------------
#
# 1. Register New Patient
# 2. Search Patient
# 3. Schedule Appointment
# 4. Return to main menu
#
# Enter your selection: 2
# Enter the mobile number of patient: 8401364728
#
# ---------------------------------------------------
# Patient Details:
#
# Name: Aakash Prajapati
# DOB: 2001-04-20
# Address: 12 Deep Bungalows, A'bad, 380015
# Phone No.: 8401364728
# e-Mail: aakash.20042001@gmail.com
# ---------------------------------------------------
#
#
# ---------------------------------------------------
# PATIENT MENU
# ---------------------------------------------------
#
# 1. Register New Patient
# 2. Search Patient
# 3. Schedule Appointment
# 4. Return to main menu
#
# Enter your selection: 3
# Enter the mobile number of patient: 84013647228
# Enter a valid 10-digit Mobile number containing only digits: 8401364728
#
# Name: Aakash Prajapati
# DOB: 2001-04-20
# Address: 12 Deep Bungalows, A'bad, 380015
# Phone No.: 8401364728
# e-Mail: aakash.20042001@gmail.com
#
# Doctors:
# 1. Dr. Batra ,M.B.B.S., Available: Tue, Thu
# 2. Dr. Reddy ,M.D., Available: Mon, Fri
#
# Enter the index number of doctor to select them for appointment: 2
#
# Enter Date (yyyy-mm-dd): 2001-04-21
# Doctor not available on selected date! Please choose another date.
#
# Enter Date (yyyy-mm-dd): 2024-04-01
